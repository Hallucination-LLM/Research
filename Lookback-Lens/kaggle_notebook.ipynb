# %% [markdown]
# ### THIS IS NOTEBOOK I RAN ON KAGGLE GPU TO MAKE SOME EXPERIMENTS
#
# ## LINK TO KAGGLE: https://www.kaggle.com/code/janeliasz/lookback-lens-test

# %%
# !git clone https://github.com/voidism/Lookback-Lens.git
# !git clone https://github.com/janeliasz/Lookback-Lens
# Out:
# Cloning into 'Lookback-Lens'...
# remote: Enumerating objects: 3825, done.
# remote: Counting objects: 100% (3825/3825), done.
# remote: Compressing objects: 100% (2777/2777), done.
# remote: Total 3825 (delta 1008), reused 3818 (delta 1001), pack-reused 0 (from 0)
# Receiving objects: 100% (3825/3825), 22.88 MiB | 11.23 MiB/s, done.
# Resolving deltas: 100% (1008/1008), done.

# %%
# import sys
# sys.path.append('/kaggle/working/Lookback-Lens/')

# %%
# !pip install -r "Lookback-Lens/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 7.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 85.9 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 43.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 9.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 29.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 15.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install -e "Lookback-Lens/transformers-4.32.0"
# Out:
# Obtaining file:///kaggle/working/Lookback-Lens/transformers-4.32.0
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.1 MB/s eta 0:00:0000:0100:01
# ...
#   Building editable for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.32.0-0.editable-py3-none-any.whl size=38517 sha256=3a4fcf03aec6a55f57966c140ef79b2158be763166f3c2f465cd9c8a7766011c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3fitl31a/wheels/14/d4/2b/1c75cb267c8ff4171d5b586ddde2c38adaa5e153b02501d817
# Successfully built transformers
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
# ...

# %%
# !gzip -d "Lookback-Lens/data/nq-open-10_total_documents_gold_at_4.jsonl.gz"

# %%
# !nvidia-smi
# Out:
# Sun Aug 18 08:49:51 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0             26W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# STEP 1 DEMO

# %%
# !python "Lookback-Lens/step01_extract_attns.py" --model-name meta-llama/Llama-2-7b-chat-hf --data-path "/kaggle/input/nq-single/nq-open-10_total_documents_gold_at_4_single.json" --output-path "Lookback-Lens/lookback-ratio-nq-7b_single.pt" --auth-token

# %% [markdown]
# GET OUTPUTS FROM STEPS 1 AND 2

# %%
# !wget "https://www.dropbox.com/scl/fi/a87iv6xw9xma6ppc5pw2h/step1and2.tar.bz?rlkey=j382rsrwu2wnfwj7sn14ai3qw&e=1&dl=1"

# %%
# !tar -xvjf "step1and2.tar.bz?rlkey=j382rsrwu2wnfwj7sn14ai3qw&e=1&dl=1" -C "Lookback-Lens"

# %% [markdown]
# STEP 3

# %%
# !python "Lookback-Lens/step03_lookback_lens.py" --anno_1 "Lookback-Lens/dump/anno-nq-7b.jsonl" --anno_2 "Lookback-Lens/dump/anno-cnndm-7b.jsonl" --lookback_ratio_1 "Lookback-Lens/dump/lookback-ratio-nq-7b.pt" --lookback_ratio_2 "Lookback-Lens/dump/lookback-ratio-cnndm-7b.pt" --auth-token
